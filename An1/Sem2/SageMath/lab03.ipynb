# %%
# 1a
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t)==x+4*y
deq2 = diff(y,t)==x+y
syst = [deq1,deq2]
C1,C2 = var('C1,C2')
ans = desolve_system(syst, [x,y], [0,C1,C2])
show(ans)
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]

# %%
# 1b
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t)==2*x-y
deq2 = diff(y,t)==x+2*y
syst = [deq1,deq2]
C1,C2 = var('C1,C2')
ans = desolve_system(syst, [x,y], [0,C1,C2])
show(ans)
# Out:
# [x(t) == (C1*cos(t) - C2*sin(t))*e^(2*t),
#  y(t) == (C2*cos(t) + C1*sin(t))*e^(2*t)]

# %%
# 1c
t = var(t)
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
eq1 = diff(x,t) == x-y+z
eq2 = diff(y,t) == x+y-z
eq3 = diff(z,t) == -y+2*z
syst = [eq1,eq2,eq3]
C1,C2,C3 = var('C1,C2,C3')
ans = desolve_system(syst, [x,y,z], [0,C1,C2,C3])
show(ans)
# Out:
# [x(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t,
#  y(t) == C1*t*e^t - C3*t*e^t + C2*e^t,
#  z(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t]

# %%
# 1d
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t)==5*x+3*y+1
deq2 = diff(y,t)==-6*x-4*y+e^(-t)
syst = [deq1,deq2]
C1,C2 = var('C1,C2')
ans = desolve_system(syst, [x,y], [0,C1,C2])
show(ans)
# Out:
# [x(t) == 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3]

# %%
# 1e
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t)==x+3*y+cos(t)
deq2 = diff(y,t)==x-y+2*t
syst = [deq1,deq2]
C1,C2 = var('C1,C2')
ans = desolve_system(syst, [x,y], [0,C1,C2])
show(ans)
# Out:
# [x(t) == 3/40*(10*C1 + 10*C2 + 9)*e^(2*t) + 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*C1 + 10*C2 + 9)*e^(2*t) - 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]

# %%
# 1f
t = var(t)
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
eq1 = diff(x,t) == x-2*y-2*z+e^(-t)
eq2 = diff(y,t) == -2*x+y+2*z
eq3 = diff(z,t) == 2*x-y-3*z+e^(-t)
syst = [eq1,eq2,eq3]
C1,C2,C3 = var('C1,C2,C3')
ans = desolve_system(syst, [x,y,z], [0,C1,C2,C3])
show(ans)
# Out:
# [x(t) == 1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) - C2*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t),
#  y(t) == -1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t),
#  z(t) == sqrt(3)*(C1 - C3)*sinh(sqrt(3)*t) - (C1 + C2 - C3)*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)]

# %%
# 2a
t = var('t')
x = function('x')(t)
y = function('y')(t)
eq1 = diff(x,t) == x+4*y
eq2 = diff(y,t) == x+y
vars = [x,y]
syst = [eq1,eq2]
in_cond = [0,1,2]
ans = desolve_system(syst,vars, in_cond)
solx = ans[0].rhs()
soly = ans[1].rhs()
g1 = plot(solx, t, -10,10, color = 'blue', ymax = 100, ymin=-100)
g2 = plot(soly, t, -10,10, color = 'red', ymax=100, ymin=-100)
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# 2b
t = var('t')
x = function('x')(t)
y = function('y')(t)
eq1 = diff(x,t) == x-y+t-1
eq2 = diff(y,t) == -2*x+4*y+cos(t)
vars = [x,y]
syst = [eq1,eq2]
in_cond = [0,0,1]
ans = desolve_system(syst,vars, in_cond)
solx = ans[0].rhs()
soly = ans[1].rhs()
g1 = plot(solx, t, -10,10, color = 'blue', ymax = 100, ymin=-100)
g2 = plot(soly, t, -10,10, color = 'red', ymax=100, ymin=-100)
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# 2c
t = var('t')
x = function('x')(t)
y = function('y')(t)
eq1 = diff(x,t) == x+2*y+e^(-t)
eq2 = diff(y,t) == -2*x+y+1
vars = [x,y]
in_cond = [0,0,1]
syst = [eq1,eq2]
ans = desolve_system(syst, vars, in_cond)
solx = ans[0].rhs()
soly = ans[1].rhs()
g1 = plot(solx, t, -10,10,ymax=100,ymin=-100, color='blue')
g2 = plot(soly, t, -10,10,ymax=100,ymin=-100, color='red')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# 2d
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
eq1 = diff(x,t) == -x+3*y+3*z+27*t^2
eq2 = diff(y,t) == 2*x-2*y-5*z+3*t
eq3 = diff(z,t) == -2*x+3*y+6*z+3
vars = [x,y,z]
syst = [eq1,eq2,eq3]
in_cond = [0,50,-30,26]
ans = desolve_system(syst, vars, in_cond)
solx = ans[0].rhs()
soly = ans[1].rhs()
solz = ans[2].rhs()
g1 = plot(solx, t, -10,10,ymax=100,ymin=-100, color='blue')
g2 = plot(soly, t, -10,10,ymax=100,ymin=-100, color='red')
g3 = plot(solz, t, -10,10,ymax=100,ymin=-100, color='green')
show(g1+g2+g3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
# 3a1
t = var('t')
x = function('x')(t)
y = function('y')(t)
eq1 = diff(x,t) == x+y
eq2 = diff(y,t) == -2*x+4*y
vars = [x,y]
in_cond = [0,3,0]
syst = [eq1,eq2]
ans = desolve_system(syst, vars, in_cond)
solx = ans[0]
soly = ans[1]
limx = limit(solx, t=infinity)
limy = limit(soly, t=infinity)
show(limx, limy)

f1(u,v) = u+v
f2(u,v) = -2*u + 4*v
systf = [f1,f2]
rangeu = [u,-10,10]
rangev = [v,-10,10]
plot_vector_field(systf, rangeu, rangev, aspect_ratio=1)
# Out:
# limit(x(t), t, +Infinity) == -Infinity limit(y(t), t, +Infinity) == -Infinity
# Graphics object consisting of 1 graphics primitive

# %%
# 3a2
t = var('t')
x = function('x')(t)
y = function('y')(t)
eq1 = diff(x,t) == x+y
eq2 = diff(y,t) == -2*x+4*y
vars = [x,y]
in_cond = [0,0,3]
syst = [eq1,eq2]
ans = desolve_system(syst, vars, in_cond)
solx = ans[0]
soly = ans[1]
limx = limit(solx, t=infinity)
limy = limit(soly, t=infinity)
show(limx, limy)

f1(u,v) = u+v
f2(u,v) = -2*u + 4*v
systf = [f1,f2]
rangeu = [u,-10,10]
rangev = [v,-10,10]
plot_vector_field(systf, rangeu, rangev, aspect_ratio=1)
# Out:
# limit(x(t), t, +Infinity) == +Infinity limit(y(t), t, +Infinity) == +Infinity
# Graphics object consisting of 1 graphics primitive

# %%
# 3a3
t = var('t')
x = function('x')(t)
y = function('y')(t)
eq1 = diff(x,t) == x+y
eq2 = diff(y,t) == -2*x+4*y
vars = [x,y]
in_cond = [0,-3,0]
syst = [eq1,eq2]
ans = desolve_system(syst, vars, in_cond)
solx = ans[0]
soly = ans[1]
limx = limit(solx, t=infinity)
limy = limit(soly, t=infinity)
show(limx, limy)

f1(u,v) = u+v
f2(u,v) = -2*u + 4*v
systf = [f1,f2]
rangeu = [u,-10,10]
rangev = [v,-10,10]
plot_vector_field(systf, rangeu, rangev, aspect_ratio=1)
# Out:
# limit(x(t), t, +Infinity) == +Infinity limit(y(t), t, +Infinity) == +Infinity
# Graphics object consisting of 1 graphics primitive

# %%
# 3a4
t = var('t')
x = function('x')(t)
y = function('y')(t)
eq1 = diff(x,t) == x+y
eq2 = diff(y,t) == -2*x+4*y
syst = [eq1,eq2]
vars = [x,y]
in_cond = [0,0,-3]
ans = desolve_system(syst, vars, in_cond)
solx = ans[0]
soly = ans[1]
limx = limit(solx, t=infinity)
limy = limit(soly, t=infinity)
show(limx,limy)

f1(u,v) = u+v
f2(u,v) = -2*u+4*v
systf = [f1,f2]
rangeu = [u,-10,10]
rangev = [v,-10,10]
plot_vector_field(systf, rangeu, rangev, aspect_ratio = 1)
# Out:
# limit(x(t), t, +Infinity) == -Infinity limit(y(t), t, +Infinity) == -Infinity
# Graphics object consisting of 1 graphics primitive

# %%
# 4
t = var('t')
x = function('x')(t)
y = function('y')(t)
eq1 = diff(x,t) == y
eq2 = diff(y,t) == -x-2*y
vars = [x,y]
syst = [eq1,eq2]
ans = desolve_system(syst, vars)
solx = ans[0]
soly = ans[1]
limx = limit(solx, t=infinity)
limy = limit(soly, t=infinity)
show(limx, limy)

f1(u,v) = v
f2(u,v) = -u-2*v
systf = [f1,f2]
rangeu = [u,-10,10]
rangev = [v,-10,10]
plot_vector_field(systf, rangeu, rangev, aspect_ratio=1)
# Out:
# limit(x(t), t, +Infinity) == 0 limit(y(t), t, +Infinity) == 0
# Graphics object consisting of 1 graphics primitive

# %%
# 5a
t = var('t')
x = function('x')(t)
y = function('y')(t)

eq1 = diff(x,t) == 2*x+y
eq2 = diff(y,t) == x+2*y
syst = [eq1,eq2]
vars = [x,y]
C1,C2 = var('C1,C2')
ans = desolve_system(syst, vars, [0,C1,C2])
solx = ans[0]
soly = ans[1]
limx = limit(solx, t=infinity)
limy = limit(soly, t=infinity)
show(limx, limy)

f1(u,v) = 2*u+v
f2(u,v) = u+2*v
systf = [f1,f2]
rangeu = [u,-10,10]
rangev = [v,-10,10]
plot_vector_field(systf, rangeu, rangev, aspect_ratio = 1)
# Out:
# limit(x(t), t, +Infinity) == limit(1/2*(C1 + C2)*e^(3*t) + 1/2*(C1 - C2)*e^t, t, +Infinity) limit(y(t), t, +Infinity) == limit(1/2*(C1 + C2)*e^(3*t) - 1/2*(C1 - C2)*e^t, t, +Infinity)
# Graphics object consisting of 1 graphics primitive

# %%
# 5b
t = var('t')
x = function('x')(t)
y = function('y')(t)

eq1 = diff(x,t) == -x-y
eq2 = diff(y,t) == x-y
syst = [eq1,eq2]
vars = [x,y]

# show(solx,soly)
# limx = limit(solx, t=infinity)
# limy = limit(soly, t=infinity)
# show(limx, limy)

f1(u,v) = -u-v
f2(u,v) = u-v
systf = [f1,f2]
rangeu = [u,-10,10]
rangev = [v,-10,10]
g1 = plot_vector_field(systf, rangeu, rangev, aspect_ratio = 1)

g= g1
for k in [1..5]:
    ans = desolve_system(syst, vars, [0,k,0])
    solx(t) = ans[0].rhs()
    soly(t) = ans[1].rhs()
    g2 = parametric_plot((solx(t), soly(t)), (t,-10,10), color='green')
    ans = desolve_system(syst, vars, [0,0,k])
    solx(t) = ans[0].rhs()
    soly(t) = ans[1].rhs()
    g3 = parametric_plot((solx(t), soly(t)), (t,-10,10), color='green')
    ans = desolve_system(syst, vars, [0,-k,0])
    solx(t) = ans[0].rhs()
    soly(t) = ans[1].rhs()
    g4 = parametric_plot((solx(t), soly(t)), (t,-10,10), color='green')
    ans = desolve_system(syst, vars, [0,0,-k])
    solx(t) = ans[0].rhs()
    soly(t) = ans[1].rhs()
    g5 = parametric_plot((solx(t), soly(t)), (t,-10,10), color='green')
    g = g + g2 + g3 + g4 + g5
g.show(xmin=-10,xmax=10,ymin=-10,ymax=10)
# asta e
# Out:
# Graphics object consisting of 21 graphics primitives

# %%
# 5c
t = var('t')
x = function('x')(t)
y = function('y')(t)

eq1 = diff(x,t) == y
eq2 = diff(y,t) == -x
syst = [eq1,eq2]
vars = [x,y]
C1,C2 = var('C1,C2')
ans = desolve_system(syst, vars)
solx = ans[0]
soly = ans[1]
limx = limit(solx, t=infinity)
limy = limit(soly, t=infinity)
show(limx, limy)
f1(u,v) = v
f2(u,v) = -u
systf = [f1(u,v),f2(u,v)]
rangeu = [u,-10,10]
rangev = [v,-10,10]
plot_vector_field(systf, rangeu, rangev, aspect_ratio = 1)
# si asta e
# Out:
# limit(x(t), t, +Infinity) == ind limit(y(t), t, +Infinity) == ind
# Graphics object consisting of 1 graphics primitive

# %%
# 5d
t = var('t')
x = function('x')(t)
y = function('y')(t)

eq1 = diff(x,t) == -2*x
eq2 = diff(y,t) == -4*x-2*y
syst = [eq1,eq2]
vars = [x,y]
C1,C2 = var('C1,C2')
ans = desolve_system(syst, vars, [0,C1,C2])
solx = ans[0]
soly = ans[1]
limx = limit(solx, t=infinity)
limy = limit(soly, t=infinity)
show(limx, limy)
f1(u,v) = -2*u
f2(u,v) = -4*u-2*v
systf = [f1,f2]
rangeu = [u,-10,10]
rangev = [v,-10,10]
plot_vector_field(systf, rangeu, rangev, aspect_ratio = 1)
# si asta e
# Out:
# limit(x(t), t, +Infinity) == 0 limit(y(t), t, +Infinity) == 0
# Graphics object consisting of 1 graphics primitive

# %%
# 5e
t = var('t')
x = function('x')(t)
y = function('y')(t)

eq1 = diff(x,t) == x-4*y
eq2 = diff(y,t) == 5*x-3*y
syst = [eq1,eq2]
vars = [x,y]
C1,C2 = var('C1,C2')
ans = desolve_system(syst, vars, [0,C1,C2])
solx = ans[0]
soly = ans[1]
limx = limit(solx, t=infinity)
limy = limit(soly, t=infinity)
show(limx, limy)
f1(u,v) = u-4*v
f2(u,v) = 5*u-3*v
systf = [f1,f2]
rangeu = [u,-10,10]
rangev = [v,-10,10]
plot_vector_field(systf, rangeu, rangev, aspect_ratio = 1)
# Out:
# limit(x(t), t, +Infinity) == 0 limit(y(t), t, +Infinity) == 0
# Graphics object consisting of 1 graphics primitive

# %%
# 5f
t = var('t')
x = function('x')(t)
y = function('y')(t)

eq1 = diff(x,t) == 3*x-y
eq2 = diff(y,t) == y
syst = [eq1,eq2]
vars = [x,y]
C1,C2 = var('C1,C2')
ans = desolve_system(syst, vars, [0,C1,C2])
solx = ans[0]
soly = ans[1]
limx = limit(solx, t=infinity)
limy = limit(soly, t=infinity)
show(limx, limy)
f1(u,v) = 3*u-v
f2(u,v) = v
systf = [f1,f2]
rangeu = [u,-10,10]
rangev = [v,-10,10]
plot_vector_field(systf, rangeu, rangev, aspect_ratio = 1)
# Out:
# limit(x(t), t, +Infinity) == limit(1/2*(2*C1 - C2)*e^(3*t) + 1/2*C2*e^t, t, +Infinity) limit(y(t), t, +Infinity) == limit(C2*e^t, t, +Infinity)
# Graphics object consisting of 1 graphics primitive
